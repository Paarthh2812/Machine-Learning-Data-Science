# %% [markdown]
# Collab Link - https://colab.research.google.com/drive/1bS2rmILoWMUuVP1kSJbUOAWXI4boD7VE?usp=sharing

# %% [markdown]
# **Python Code for Multiple Linear Regression**
#
# CSV Data Link - https://drive.google.com/file/d/17CMsfrhVergheHVoYRq2b0IMWdHusK6C/view?usp=sharing

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Regression_Data.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# %% [markdown]
# Predicting Values of Test_Set & Comparing

# %%
y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

# %% [markdown]
# R-squared Value

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)

# %% [markdown]
# ## Code by Paarth Parikh
#
# Multiple Linear Regression
