# %% [markdown]
# Collab Link - https://colab.research.google.com/drive/12T6ull3w5hxH1q1wgVrks35gghYjFspa?usp=sharing

# %% [markdown]
# **Python Program for Support Vector Regression**
#
# CSV Data Link - https://drive.google.com/file/d/17CMsfrhVergheHVoYRq2b0IMWdHusK6C/view?usp=sharing

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Regression_Data.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
y = y.reshape(len(y),1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# Feature Scaling as it is necessary for Support Vector

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X_train = sc_X.fit_transform(X_train)
y_train = sc_y.fit_transform(y_train)

# %% [markdown]
# Fitting the Model

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X_train, y_train)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# SVR()

# %% [markdown]
# Predicting & Comparing Values

# %%
y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)).reshape(-1,1))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[434.05 431.23]
#  [457.94 460.01]
#  [461.03 461.14]
#  ...
#  [470.6  473.26]
#  [439.42 438.  ]
#  [460.92 463.28]]

# %% [markdown]
# R-Squared Value

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.948078404998626

# %% [markdown]
# ## Code by Paarth Parikh
#
# Support Vector Regression
