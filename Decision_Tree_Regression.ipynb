# %% [markdown]
# Collab Link - https://colab.research.google.com/drive/19GbCNVlcHuKb9cjEDGl8XZncT_Rn0Z6m?usp=sharing

# %% [markdown]
# **Python Program for Decision Tree Regression**
#
# CSV Data Link - https://drive.google.com/file/d/17CMsfrhVergheHVoYRq2b0IMWdHusK6C/view?usp=sharing

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Regression_Data.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# Fitting the Model

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# Predicting and Comparing the Values

# %%
y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[431.28 431.23]
#  [459.59 460.01]
#  [460.06 461.14]
#  ...
#  [471.46 473.26]
#  [437.76 438.  ]
#  [462.74 463.28]]

# %% [markdown]
# R-Squared Value

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.922905874177941

# %% [markdown]
# ## Code by Paarth Parikh
#
# Decision Tree Regression
